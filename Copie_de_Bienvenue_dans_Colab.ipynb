# %% [markdown]
# <a href="https://colab.research.google.com/github/hdiddoubouchraencg-cell/machine_learning_project-/blob/main/Copie_de_Bienvenue_dans_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.read_csv('/content/Masi 20 Historical Data.csv.crdownload')
print(df.head())

# %%
print("DataFrame Info:")
df.info()

print("\nDescriptive Statistics:")
print(df.describe(include='all'))

print("\nMissing Values:")
print(df.isnull().sum())

# %%
import pandas as pd
import numpy as np

# Reload the DataFrame to ensure 'Price' column is a string type for .str accessor.
# This is necessary because previous execution already converted 'Price' to float.
df = pd.read_csv('/content/Masi 20 Historical Data.csv.crdownload')

# 1. Remove commas from 'Price' and convert to numeric (float)
df['Price'] = df['Price'].str.replace(',', '', regex=False).astype(float)

# 2. Convert 'Date' to datetime objects
df['Date'] = pd.to_datetime(df['Date'])

# 3. Set 'Date' as the DataFrame index
df = df.set_index('Date')

# 4. Drop all columns except for 'Price'
df = df[['Price']]

# 5. Check for and handle any remaining missing values in the 'Price' column
# Fixed: Use .ffill() directly and assign back to avoid FutureWarning.
df['Price'] = df['Price'].ffill()

print("DataFrame after preprocessing:")
print(df.head())
print("\nDataFrame Info after preprocessing:")
df.info()
print("\nMissing Values after preprocessing:")
print(df.isnull().sum())

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
import numpy as np
import matplotlib.pyplot as plt

# The original 'data' variable is already available from previous steps and is an array of original prices.
# We need a scaler to inverse transform the predictions and actual values.
# Create an instance of MinMaxScaler and fit it to the original 'data'.
scaler_inverse = MinMaxScaler(feature_range=(0, 1))
scaler_inverse.fit(data)

# Reshape X_train_reshaped and X_test_reshaped from 3D to 2D for Linear Regression
X_train_lr = X_train_reshaped.reshape(X_train_reshaped.shape[0], X_train_reshaped.shape[1] * X_train_reshaped.shape[2])
X_test_lr = X_test_reshaped.reshape(X_test_reshaped.shape[0], X_test_reshaped.shape[1] * X_test_reshaped.shape[2])

# FIX: Ensure y_train has the same number of samples as X_train_lr
# The error message indicates X_train_lr has 574 samples and y_train has 576 samples.
# Truncate y_train to match the length of X_train_lr.
if len(y_train) != X_train_lr.shape[0]:
    print(f"Warning: y_train length ({len(y_train)}) inconsistent with X_train_lr length ({X_train_lr.shape[0]}). Truncating y_train.")
    y_train = y_train[:X_train_lr.shape[0]]

# Initialize and train Linear Regression model
linear_model = LinearRegression()
linear_model.fit(X_train_lr, y_train)

# Make predictions on the test data
y_pred_lr_scaled = linear_model.predict(X_test_lr)

# FIX: Ensure y_test has the same number of samples as y_pred_lr_scaled (which is based on X_test_lr)
# The previous error indicated y_test had 144 samples and y_pred_lr_actual had 143 samples.
if len(y_test) != y_pred_lr_scaled.shape[0]:
    print(f"Warning: y_test length ({len(y_test)}) inconsistent with y_pred_lr_scaled length ({y_pred_lr_scaled.shape[0]}). Truncating y_test.")
    y_test = y_test[:y_pred_lr_scaled.shape[0]]

# Inverse transform y_test and y_pred_lr_scaled back to original price scale
y_test_actual = scaler_inverse.inverse_transform(y_test.reshape(-1, 1))
y_pred_lr_actual = scaler_inverse.inverse_transform(y_pred_lr_scaled.reshape(-1, 1))

# Calculate evaluation metrics
mse_lr = mean_squared_error(y_test_actual, y_pred_lr_actual)
rmse_lr = np.sqrt(mse_lr)
mae_lr = mean_absolute_error(y_test_actual, y_pred_lr_actual)

print(f"Linear Regression MSE: {mse_lr:.4f}")
print(f"Linear Regression RMSE: {rmse_lr:.4f}")
print(f"Linear Regression MAE: {mae_lr:.4f}")

# Visualize actual vs. predicted prices
plt.figure(figsize=(14, 7))
plt.plot(y_test_actual, label='Actual Prices', color='blue')
plt.plot(y_pred_lr_actual, label='Predicted Prices (Linear Regression)', color='red', linestyle='--')
plt.title('Actual vs. Predicted Prices (Linear Regression)')
plt.xlabel('Time Step')
plt.ylabel('Price')
plt.legend()
plt.grid(True)
plt.show()

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
import numpy as np
import matplotlib.pyplot as plt

# The original 'data' variable is already available from previous steps and is an array of original prices.
# We need a scaler to inverse transform the predictions and actual values.
# Create an instance of MinMaxScaler and fit it to the original 'data'.
scaler_inverse = MinMaxScaler(feature_range=(0, 1))
scaler_inverse.fit(data)

# Reshape X_train_reshaped and X_test_reshaped from 3D to 2D for Linear Regression
X_train_lr = X_train_reshaped.reshape(X_train_reshaped.shape[0], X_train_reshaped.shape[1] * X_train_reshaped.shape[2])
X_test_lr = X_test_reshaped.reshape(X_test_reshaped.shape[0], X_test_reshaped.shape[1] * X_test_reshaped.shape[2])

# FIX: Ensure y_train has the same number of samples as X_train_lr
# The error message indicates X_train_lr has 574 samples and y_train has 576 samples.
# Truncate y_train to match the length of X_train_lr.
if len(y_train) != X_train_lr.shape[0]:
    print(f"Warning: y_train length ({len(y_train)}) inconsistent with X_train_lr length ({X_train_lr.shape[0]}). Truncating y_train.")
    y_train = y_train[:X_train_lr.shape[0]]

# Initialize and train Linear Regression model
linear_model = LinearRegression()
linear_model.fit(X_train_lr, y_train)

# Make predictions on the test data
y_pred_lr_scaled = linear_model.predict(X_test_lr)

# FIX: Ensure y_test has the same number of samples as y_pred_lr_scaled (which is based on X_test_lr)
# The previous error indicated y_test had 144 samples and y_pred_lr_actual had 143 samples.
if len(y_test) != y_pred_lr_scaled.shape[0]:
    print(f"Warning: y_test length ({len(y_test)}) inconsistent with y_pred_lr_scaled length ({y_pred_lr_scaled.shape[0]}). Truncating y_test.")
    y_test = y_test[:y_pred_lr_scaled.shape[0]]

# Inverse transform y_test and y_pred_lr_scaled back to original price scale
y_test_actual = scaler_inverse.inverse_transform(y_test.reshape(-1, 1))
y_pred_lr_actual = scaler_inverse.inverse_transform(y_pred_lr_scaled.reshape(-1, 1))

# Calculate evaluation metrics
mse_lr = mean_squared_error(y_test_actual, y_pred_lr_actual)
rmse_lr = np.sqrt(mse_lr)
mae_lr = mean_absolute_error(y_test_actual, y_pred_lr_actual)

print(f"Linear Regression MSE: {mse_lr:.4f}")
print(f"Linear Regression RMSE: {rmse_lr:.4f}")
print(f"Linear Regression MAE: {mae_lr:.4f}")

# Visualize actual vs. predicted prices
plt.figure(figsize=(14, 7))
plt.plot(y_test_actual, label='Actual Prices', color='blue')
plt.plot(y_pred_lr_actual, label='Predicted Prices (Linear Regression)', color='red', linestyle='--')
plt.title('Actual vs. Predicted Prices (Linear Regression)')
plt.xlabel('Time Step')
plt.ylabel('Price')
plt.legend()
plt.grid(True)
plt.show()
